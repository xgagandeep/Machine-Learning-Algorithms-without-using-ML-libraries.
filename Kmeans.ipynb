# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples = 500,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1],c=y)

# %%
k = 5
color=["green","red","blue","yellow","orange"]
clusters = {}
for i in range(k):
    center = 10*(2*np.random.random((X.shape[1],))-1)
    points = []
    cluster = {
        "center":center,
        "points":points,
        'colors' : color[i]
    }
    clusters[i] = cluster

# %%
clusters
# Out:
# {0: {'center': array([6.75738608, 9.35249822]),
#   'points': [],
#   'colors': 'green'},
#  1: {'center': array([5.50198074, 0.80958053]), 'points': [], 'colors': 'red'},
#  2: {'center': array([-2.32229689, -0.82161907]),
#   'points': [],
#   'colors': 'blue'},
#  3: {'center': array([-6.75099535, -0.42306789]),
#   'points': [],
#   'colors': 'yellow'},
#  4: {'center': array([-6.63350928, -0.98429457]),
#   'points': [],
#   'colors': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
def assignPointsToClusters(clusters):
    for ix in range(X.shape[0]):
        dist = []
        curr_x = X[ix]
        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)
        current_cluster = np.argmin(dist)
        clusters[current_cluster]['points'].append(curr_x)
def updateClusters(clusters):
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        if pts.shape[0]>0:
            new_u = pts.mean(axis=0)
            clusters[kx]['center'] = new_u
            clusters[kx]['points'] = []
def plotClusters(clusters):
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        print(pts.shape)
        try:
            plt.scatter(pts[:,0],pts[:,1])
        except:
            pass
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (107, 2)
# (47, 2)
# (111, 2)
# (85, 2)
# (150, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (96, 2)
# (82, 2)
# (112, 2)
# (110, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (100, 2)
# (96, 2)
# (105, 2)
# (99, 2)

# %%
assignPointsToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (100, 2)
# (98, 2)
# (103, 2)
# (99, 2)
